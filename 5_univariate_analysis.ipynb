# %%
import pandas as pd

# %%
df = pd.read_csv("ambitionbox_jobs.csv", index_col=0, na_values=['--'])

# %%
df.head()
# Out:
#         name                     sector                        location  \
# 0        TCS  IT Services & Consulting   Bengaluru +441 other locations
# 1  Accenture  IT Services & Consulting   Bengaluru +259 other locations
# 2      Wipro  IT Services & Consulting   Hyderabad +373 other locations
# 3  Cognizant  IT Services & Consulting   Hyderabad +231 other locations
# 4  Capgemini  IT Services & Consulting   Bengaluru +180 other locations
#
#    rating reviews   jobs
# 0     3.3    1.1L   4.4k
# 1     3.7   73.1k  35.7k
# 2     3.6   64.8k    367
# 3     3.7   61.2k    466
# 4     3.6     53k   2.1k

# %%
df.sample(5)
# Out:
#                                           name                     sector  \
# 3689                      LatentView Analytics  IT Services & Consulting
# 4599                          Triveni Turbines      Electrical Equipment
# 130                                      IQVIA         Clinical Research
# 1538          Sykes Business Services Of India                       BPO
# 7790  Karnataka Power Transmission Corporation                     Power
#
#                            location  rating reviews jobs
# 3689    Chennai +11 other locations     3.6     300   30
# 4599  Bengaluru +17 other locations     3.5     241  NaN
# 130   Bengaluru +67 other locations     3.7    5.2k   31
# 1538  Hyderabad +15 other locations     3.4     693   31
# 7790  Bengaluru +36 other locations     4.2     143  NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9980 entries, 0 to 9979
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      9980 non-null   object
#  1   sector    9980 non-null   object
#  2   location  9705 non-null   object
#  3   rating    9977 non-null   float64
#  4   reviews   9977 non-null   object
#  5   jobs      6155 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 545.8+ KB

# %%
df.isnull().sum()
# Out:
# name           0
# sector         0
# location     275
# rating         3
# reviews        3
# jobs        3825
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9975    False
# 9976    False
# 9977    False
# 9978    False
# 9979    False
# Length: 9980, dtype: bool

# %%
import seaborn as sns

# %%
sns.boxplot(df['rating'])
# Out:
# <Axes: ylabel='rating'>

# %%
import matplotlib.pyplot as plt
import numpy as np
# Sample data
data = np.array([5, 7, 8, 12, 15, 18, 21, 24, 25, 30, 50])
# Create boxplot
plt.boxplot(data, vert=False, patch_artist=True, boxprops=dict(facecolor='lightblue'))
plt.title("Boxplot Showing IQR")
plt.xlabel("Values")
plt.show()

# %%
dfs = pd.read_csv('Teen_Mental_Health_Dataset.csv')

# %%
dfs.sample(5)
# Out:
#       age  gender  daily_social_media_hours platform_usage  sleep_hours  \
# 260    14    male                       5.7           Both          6.6
# 2484   14    male                       7.2      Instagram          4.8
# 1308   18  female                       5.2      Instagram          6.0
# 1726   13  female                       6.1         TikTok          4.4
# 2375   14    male                       3.5         TikTok          6.7
#
#       screen_time_before_sleep  academic_performance  physical_activity  \
# 260                        1.1                  2.65                0.3
# 2484                       2.1                  2.00                0.7
# 1308                       1.9                  2.72                1.8
# 1726                       2.8                  2.20                1.8
# 2375                       0.8                  2.82                0.2
#
#      social_interaction_level  stress_level  anxiety_level depression_risk
# ...

# %%
# Count Plot

sns.countplot(dfs['gender'], palette='viridis')
dfs['gender'].value_counts()
# Out:
# C:\Users\sathv\AppData\Local\Temp\ipykernel_26572\33477352.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(dfs['gender'], palette='viridis')
# gender
# female    1255
# male      1245
# Name: count, dtype: int64

# %%
sns.countplot(dfs['depression_risk'])
# Out:
# <Axes: xlabel='count', ylabel='depression_risk'>

# %%
dfs['depression_risk'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(dfs['stress_level'], bins=15)
dfs['stress_level'].value_counts()
# Out:
# stress_level
# 10    373
# 1     322
# 5     249
# 4     247
# 7     232
# 3     228
# 6     222
# 9     220
# 8     212
# 2     195
# Name: count, dtype: int64

# %%
sns.distplot(dfs['stress_level'])
# Out:
# C:\Users\sathv\AppData\Local\Temp\ipykernel_26572\2921834620.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dfs['stress_level'])
# <Axes: xlabel='stress_level', ylabel='Density'>

# %%
sns.boxplot(dfs['age'])
# Out:
# <Axes: ylabel='age'>

# %%
dfs['age'].min()
# Out:
# 13

# %%
dfs['age'].max()
# Out:
# 19

# %%
dfs['age'].mean()
# Out:
# np.float64(15.978)

# %%
dfs['stress_level'].skew()
# Out:
# np.float64(-0.018002189823820788)
