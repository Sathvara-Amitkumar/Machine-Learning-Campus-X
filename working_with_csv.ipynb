# %%
import pandas as pd

# %%
df = pd.read_csv("Countries.csv", index_col="country", usecols=['country','capital_city','region'])

# %%
df.head()
# Out:
#                  capital_city           region
# country
# Afghanistan             Kabul    Southern Asia
# Albania                Tirana  Southern Europe
# Algeria               Algiers  Northern Africa
# Andorra      Andorra la Vella  Southern Europe
# Angola                 Luanda    Middle Africa

# %%
for chunk in pd.read_csv("Countries.csv", chunksize=50):
    print(chunk.shape)
# Out:
# (50, 64)
# (50, 64)
# (50, 64)
# (44, 64)

# %%
df.head()
# Out:
#        country                             country_long        currency  \
# 0  Afghanistan             Islamic State of Afghanistan  Afghan afghani
# 1      Albania                      Republic of Albania    Albanian lek
# 2      Algeria  People's Democratic Republic of Algeria  Algerian dinar
# 3      Andorra                  Principality of Andorra            Euro
# 4       Angola              People's Republic of Angola  Angolan kwanza
#
#        capital_city           region continent   demonym  latitude  longitude  \
# 0             Kabul    Southern Asia      Asia    Afghan      33.0       65.0
# 1            Tirana  Southern Europe    Europe  Albanian      41.0       20.0
# 2           Algiers  Northern Africa    Africa  Algerian      28.0        3.0
# 3  Andorra la Vella  Southern Europe    Europe  Andorran      42.5        1.5
# 4            Luanda    Middle Africa    Africa   Angolan     -12.5       18.5
#
#    agricultural_land  ...  population  women_parliament_seats_pct  \
# 0           383560.0  ...    41128771                    27.01610
# 1            11655.5  ...     2775634                    35.71430
# 2           413588.0  ...    44903225                     8.10811
# 3              187.2  ...       79824                    46.42860
# 4           569525.0  ...    35588987                    33.63640
#
#    rural_population  urban_population  press  democracy_score  democracy_type  \
# 0          30181937          10946834   2.14             2.97   Authoritarian
# 1           1004807           1770827   2.62             5.98   Hybrid regime
# 2          11328186          33575039   1.71             3.50   Authoritarian
# 3              9730             70094   3.17             0.00         Unknown
# 4          11359649          24229338   2.24             3.62   Authoritarian
#
#    median_age      political_leader               title
# 0        12.9          Ashraf Ghani           President
# 1        33.7              Edi Rama      Prime Minister
# 2        24.0  Abdelmadjid Tebboune           President
# 3        38.9   Xavier Espot Zamora  Head of Government
# 4        12.4         João Lourenço           President
#
# [5 rows x 64 columns]

# %%
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url, headers=headers)
data = StringIO(req.text)

df = pd.read_csv(data)
df.columns
# Out:
# Index(['Country', 'Region'], dtype='object')

# %%
df
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %%
df = pd.read_csv("Countries.csv", skiprows=[0,1], header=1)
df
# Out:
#                  Algeria People's Democratic Republic of Algeria  \
# 0                Andorra                 Principality of Andorra
# 1                 Angola             People's Republic of Angola
# 2    Antigua and Barbuda                     Antigua and Barbuda
# 3              Argentina                      Argentine Republic
# 4                Armenia                     Republic of Armenia
# ..                   ...                                     ...
# 186              Vietnam           Socialist Republic of Vietnam
# 187   West Bank and Gaza                      West Bank and Gaza
# 188                Yemen                       Republic of Yemen
# 189               Zambia                      Republic of Zambia
# 190             Zimbabwe                    Republic of Zimbabwe
#
#             Algerian dinar           Algiers     Northern Africa    Africa  \
# 0                     Euro  Andorra la Vella     Southern Europe    Europe
# 1           Angolan kwanza            Luanda       Middle Africa    Africa
# 2    East Caribbean dollar      Saint John's           Caribbean  Americas
# 3           Argentine peso      Buenos Aires       South America  Americas
# 4            Armenian dram           Yerevan        Western Asia      Asia
# ..                     ...               ...                 ...       ...
# 186        Vietnamese dong             Hanoi  South-Eastern Asia      Asia
# 187     Israeli new shekel          Ramallah        Western Asia      Asia
# 188            Yemeni rial            Sana'a        Western Asia      Asia
# 189     New Zambian kwacha            Lusaka      Eastern Africa    Africa
# 190            U.S. dollar            Harare      Eastern Africa    Africa
#
#         Algerian       28.0         3.0   413588.0  ...  44903225  8.10811  \
# 0       Andorran  42.500000    1.500000      187.2  ...     79824  46.4286
# 1        Angolan -12.500000   18.500000   569525.0  ...  35588987  33.6364
# 2       Antiguan  17.050000  -61.800000       90.0  ...     93763  11.1111
# 3      Argentine -34.000000  -64.000000  1083820.0  ...  46234830  44.7471
# 4       Armenian  40.000000   45.000000    16760.0  ...   2780469  35.5140
# ..           ...        ...         ...        ...  ...       ...      ...
# 186   Vietnamese  16.166667  107.833333   123600.0  ...  98186856  30.2605
# 187  Palestinian  31.900000   35.200000     4449.0  ...   5043612      NaN
# 188       Yemeni  15.000000   48.000000   234520.0  ...  33696614   0.0000
# 189      Zambian -15.000000   30.000000   238360.0  ...  20017675  15.0602
# 190   Zimbabwean -20.000000   30.000000   162000.0  ...  16320537  30.5660
#
#      11328186  33575039  1.71   3.5     Authoritarian  24.0  \
# 0        9730     70094  3.17  0.00           Unknown  38.9
# 1    11359649  24229338  2.24  3.62     Authoritarian  12.4
# 2       70935     22828  0.00  0.00           Unknown  31.1
# 3     3538352  42696478  2.76  7.02  Flawed democracy  27.6
# 4     1012841   1767628  2.70  4.79     Hybrid regime  30.8
# ..        ...       ...   ...   ...               ...   ...
# 186  60123739  38063117  1.04  3.08     Authoritarian  28.4
# 187   1145354   3898258  1.75  4.39     Hybrid regime  15.4
# 188  20491585  13205029  1.27  1.95     Authoritarian  14.8
# 189  10857387   9160288  2.15  5.61     Hybrid regime  13.2
# 190  11033499   5287038  1.85  3.16     Authoritarian  14.2
#
#       Abdelmadjid Tebboune                                 President
# 0      Xavier Espot Zamora                        Head of Government
# 1            João Lourenço                                 President
# 2            Gaston Browne                            Prime Minister
# 3        Alberto Fernández                                 President
# 4          Nikol Pashinyan                            Prime Minister
# ..                     ...                                       ...
# 186       Nguyễn Phú Trọng  General Secretary of the Communist Party
# 187                    NaN                                       NaN
# 188  Abdrabbuh Mansur Hadi                                 President
# 189            Edgar Lungu                                 President
# 190     Emmerson Mnangagwa                                 President
#
# [191 rows x 64 columns]

# %%
def rename(name):
    if name == 'Islamic State of Afghanistan':
        return "ISA"
    else:
        return name
print(rename('Islamic State of Afghanistan'))
# Out:
# ISA

# %%
df = pd.read_csv("Countries.csv", converters={'country_long':rename})

# %%
df.head()
# Out:
#        country                             country_long        currency  \
# 0  Afghanistan                                      ISA  Afghan afghani
# 1      Albania                      Republic of Albania    Albanian lek
# 2      Algeria  People's Democratic Republic of Algeria  Algerian dinar
# 3      Andorra                  Principality of Andorra            Euro
# 4       Angola              People's Republic of Angola  Angolan kwanza
#
#        capital_city           region continent   demonym  latitude  longitude  \
# 0             Kabul    Southern Asia      Asia    Afghan      33.0       65.0
# 1            Tirana  Southern Europe    Europe  Albanian      41.0       20.0
# 2           Algiers  Northern Africa    Africa  Algerian      28.0        3.0
# 3  Andorra la Vella  Southern Europe    Europe  Andorran      42.5        1.5
# 4            Luanda    Middle Africa    Africa   Angolan     -12.5       18.5
#
#    agricultural_land  ...  population  women_parliament_seats_pct  \
# 0           383560.0  ...    41128771                    27.01610
# 1            11655.5  ...     2775634                    35.71430
# 2           413588.0  ...    44903225                     8.10811
# 3              187.2  ...       79824                    46.42860
# 4           569525.0  ...    35588987                    33.63640
#
#    rural_population  urban_population  press  democracy_score  democracy_type  \
# 0          30181937          10946834   2.14             2.97   Authoritarian
# 1           1004807           1770827   2.62             5.98   Hybrid regime
# 2          11328186          33575039   1.71             3.50   Authoritarian
# 3              9730             70094   3.17             0.00         Unknown
# 4          11359649          24229338   2.24             3.62   Authoritarian
#
#    median_age      political_leader               title
# 0        12.9          Ashraf Ghani           President
# 1        33.7              Edi Rama      Prime Minister
# 2        24.0  Abdelmadjid Tebboune           President
# 3        38.9   Xavier Espot Zamora  Head of Government
# 4        12.4         João Lourenço           President
#
# [5 rows x 64 columns]
